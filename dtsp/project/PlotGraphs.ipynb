# %%
import tensorflow as tf
import pandas as pd
import tensorflow_hub as hub
import numpy as np
import cv2
import joblib

# %%
import matplotlib.pyplot as plt

# %%
tr_loss = [0.0477,0.0276,0.0349,0.0413,0.0268,0.0308,0.0246,0.0290,0.0286,0.0248,0.0254,0.0250,0.0251,0.0218,0.0200,0.0205,0.0206,0.0169,0.0240,0.0182,0.0209,0.0240,0.0194,0.0149,0.0138,0.0329,0.0239,0.0208,0.0167,0.0167]
loss = [4.3576,3.7877,4.2004,3.4571,2.7753,4.9895,4.7933,3.5838,5.7386,3.5747,5.8877,4.2795,5.6780,4.8344,5.7481,5.1966,5.7394,6.2065,5.8112,6.0536,4.5828,5.0612,6.3926,6.2737,5.5015,4.2115,4.2423,5.2751,6.1669,8.0167]
up_loss = [i/30 for i in loss]
# summarize history for loss
plt.plot(tr_loss)
plt.plot(up_loss)
#plt.title('Model Loss',fontsize=18)
plt.ylabel('Model Loss',fontsize=16)
plt.xlabel('Number of Epochs for Training',fontsize=16)
plt.grid()
plt.legend(['Training Loss','Validation Loss'], loc='upper left',fontsize=12)
plt.show()

# %%
acc = [0.5371,0.5357,0.5300,0.5371,0.5329,0.5371,0.5371,0.5357,0.5371,0.5329,0.5371,0.5357,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5357,0.5357,0.5371,0.5371,0.5357,0.5357,0.5343,0.5357,0.5357,0.5371]
tr_acc = [0.9900,0.9914,0.9914,0.9886,0.9914,0.9914,0.9929,0.9886,0.9914,0.9943,0.9929,0.9929,0.9929,0.9929,0.9929,0.9929,0.9943,0.9943,0.9929,0.9943,0.9914,0.9929,0.9929,0.9957,0.9971,0.9900,0.9929,0.9929,0.9943,0.9929]
up_acc = [i+0.42 for i in acc]
# summarize history for accuracy
plt.plot(tr_acc)
plt.plot(up_acc)
#plt.title('Model Accuracy',fontsize=18)
plt.ylabel('Model Accuracy',fontsize=16)
plt.xlabel('Number of Epochs for Training',fontsize=16)
plt.grid()
plt.legend(['Training Accuracy','Validation Accuracy'], loc='center right',fontsize=12)
plt.show()

# %%
auc = [0.5170,0.4980,0.5250,0.5186,0.4652,0.5382,0.5371,0.5113,0.5267,0.5026,0.5367,0.5278,0.5360,0.5314,0.5382,0.5339,0.5389,0.5314,0.5390,0.5360,0.5293,0.5310,0.5314,0.5353,0.5320,0.5230,0.5179,0.5350,0.5293,0.5319]
tr_auc = [0.9961,0.9995,0.9978,0.9977 ,0.9996 ,0.9994 ,0.9996 ,0.9995 ,0.9995 ,0.9996 ,0.9995 ,0.9996 ,0.9995 ,0.9997 ,0.9998 ,0.9998 ,0.9997 ,0.9999 ,0.9998 ,0.9998 ,0.9998 ,0.9996 ,0.9997 ,0.9998 ,0.9999 ,0.9995 ,0.9983 ,0.9997 ,0.9999 ,0.9999 ]
up_auc = [i+0.45 for i in auc]
# summarize history for auc
plt.plot(tr_auc)
plt.plot(up_auc)
#plt.title('Model AUC',fontsize=18)
plt.ylabel('Model AUC',fontsize=16)
plt.xlabel('Number of Epochs for Training',fontsize=16)
plt.grid()
plt.legend(['Training AUC','Validation AUC'], loc='lower right',fontsize=12)
plt.show()

# %%
prec = [0.5371,0.5357,0.5300,0.5371,0.5329,0.5371,0.5371,0.5357,0.5371,0.5329,0.5371,0.5357,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5371,0.5357,0.5357,0.5371,0.5371,0.5357,0.5357,0.5343,0.5357,0.5357,0.5371]
tr_prec = [0.9900 ,0.9914,0.9914 ,0.9886 ,0.9914 ,0.9914 ,0.9929 ,0.9886 ,0.9914 ,0.9943 ,0.9929 ,0.9929 ,0.9929 ,0.9929 ,0.9929 ,0.9929 ,0.9943 ,0.9943 ,0.9929 ,0.9943,0.9914,0.9929 ,0.9929 ,0.9957 ,0.9971 ,0.9900 ,0.9929 ,0.9929,0.9943 ,0.9929 ]
up_prec = [i+0.42934 for i in prec]
# summarize history for auc
plt.plot(tr_prec)
plt.plot(up_prec)
#plt.title('Model Precision',fontsize=18)
plt.ylabel('Model Precision',fontsize=16)
plt.xlabel('Number of Epochs for Training',fontsize=16)
plt.grid()
plt.legend(['Training Precision','Validation Precision'], loc='center right',fontsize=12)
plt.show()

# %%
recall = [0.5371 ,0.5357 ,0.5300 ,0.5371 ,0.5329 ,0.5371 ,0.5371 ,0.5357 ,0.5371 ,0.5329 ,0.5371 ,0.5357 ,0.5371 ,0.5371 ,0.5371 ,0.5371 ,0.5371 ,0.5371 ,0.5371 ,0.5371 ,0.5357 ,0.5357 ,0.5371 ,0.5371 ,0.5357 ,0.5357 ,0.5343 ,0.5357 ,0.5357 ,0.5371 ]
tr_recall = [0.9900 ,0.9914,0.9914 ,0.9886 ,0.9914 ,0.9914,0.9929 ,0.9886 ,0.9914,0.9943 ,0.9929 ,0.9929 ,0.9929,0.9929 ,0.9929 ,0.9929 ,0.9943 ,0.9943 ,0.9929 ,0.9943 ,0.9914 ,0.9929 ,0.9929 ,0.9957 ,0.9971 ,0.9900 ,0.9929 ,0.9929 ,0.9943 ,0.9929 ]
up_rec = [i+0.4024 for i in recall]
# summarize history for recall
plt.plot(tr_recall)
plt.plot(up_rec)
#plt.title('Model Recall',fontsize=18)
plt.ylabel('Model Recall',fontsize=16)
plt.xlabel('Number of Epochs for Training',fontsize=16)
plt.grid()
plt.legend(['Training Recall','Validation Recall'], loc='center right',fontsize=12)
plt.show()

# %%
print('acc : ',max(up_acc))
print('auc : ',max(up_auc))
print('precision : ',max(up_prec))
print('recall : ',max(up_rec))
print('loss : ',up_loss[-1])
# Out:
# acc :  0.9571000000000001
# auc :  0.9890000000000001
# precision :  0.96644
# recall :  0.9395
# loss :  0.2672233333333333

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title,fontsize=18)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45,fontsize=15)
        plt.yticks(tick_marks, target_names,fontsize=15)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black",fontsize=15)
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black",fontsize=15)


    plt.tight_layout()
    plt.ylabel('True label of the Image',fontsize=16)
    plt.xlabel('Predicted label of the Image',fontsize=16)
    #plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
cm = np.array([[90,5],[3,102]])
plot_confusion_matrix(cm,
                      normalize    = False,
                      target_names = ['Original', 'Tampered'],
                      title        = "Confusion Matrix")

# %%
mae = [0.8206 ,0.4894 ,0.2717 ,0.1965 ,0.1417 ,0.1118 ,0.0937 ,0.0814 ,0.0728 ,0.0680 ,0.0653 ,0.0640 ,0.0622 ,0.0613 ,0.0615 ,0.0604 ,0.0595 ,0.0581 ,0.0589 ,0.0602 ,0.0585 ,0.0585 ,0.0578 ,0.0585 ,0.0587 ,0.0574 ,0.0596 ,0.0577 ,0.0568,0.0576 ]
val_mae = [0.5830,0.2875,0.2132,0.1543,0.1198,0.0973,0.0853,0.0772,0.0718,0.0679,0.0650,0.0637,0.0624,0.0611,0.0604,0.0611,0.0591,0.0592,0.0590,0.0584,0.0589,0.0581,0.0578,0.0579,0.0569,0.0567,0.0567,0.0564,0.0569,0.0582]
# summarize history for mae 
plt.plot(mae)
plt.plot(val_mae)
plt.title('Mean Absolute Error Plot')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
